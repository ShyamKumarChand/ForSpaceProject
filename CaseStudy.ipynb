# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
case_study = pd.read_excel('Downloads/Case Study - Deep Dive Analysis (1).xlsx',encoding='latin-1')

# %%
# !pip install xlrd

# %%
case_study.head()
# Out:
#    Zone Region     Manufacturer     Brand                       Subbrand  \
# 0  East  Rural  GLAXOSMITHKLINE  HORLICKS                  HORLICKS LITE
# 1  East  Rural  GLAXOSMITHKLINE  HORLICKS                WOMENS HORLICKS
# 2  East  Rural  GLAXOSMITHKLINE     BOOST                   BOOST SPORTS
# 3  East  Rural  GLAXOSMITHKLINE  HORLICKS  HORLICKS HEALTH AND NUTRITION
# 4  East  Rural  GLAXOSMITHKLINE     BOOST        BOOST HEALTH AND ENERGY
#
#                                                 Item PackSize     Packtype  \
# 0                  HORLICKS LITE 500 GMS REFILL PACK  500 GMS  REFILL PACK
# 1                WOMENS HORLICKS 500 GMS REFILL PACK  500 GMS  REFILL PACK
# 2                   BOOST SPORTS 500 GMS REFILL PACK  500 GMS  REFILL PACK
# 3  HORLICKS HEALTH AND NUTRITION 500 GMS REFILL PACK  500 GMS  REFILL PACK
# 4      BOOST HEALTH AND ENERGYÂ  500 GMS REFILL PACK  500 GMS  REFILL PACK
#
#        month  Value Offtake(000 Rs)
# 0 2019-01-01               4883.050
# ...

# %% [markdown]
# There are multiple instances where the Value Sales have decreased for different manufacturers in the last month compared to the month before that and it is important for the business to understand the exact area or level from where the drop is coming from
#
# Objective:
# To create a generic Python function which can do a deep dive analysis and give out exact focus area which are behind the cause of drop of Value Sales for a particular Manufacturer
#
# Steps to follow:
# 1. Check if there is a drop in the Value Sales in the target month compared to last month
# 2. If Step 1 shows an increase then print "There is no drop in the sales for a <particular manufacturer> in the <specified time period>"
# 3. If Step 1 shows a drop, then proceed by picking different deep dive options: Product level, Geographical level
# 4. To do a deep dive - calculate the growth rate of sales in the target month and contribution to overall value sales
# 5. Take a product of the above two metrics to get a decisive metric which can then be sorted accordingly to get the actual focus area
# 6. Expected final input to the function:
# func(Manufacturer = "X", target_period = "May2019", reference_period = "Apr2019")
# 7. Expected final output of the function:
# Manufacturer focus_area growth_rate contribution product
# X F1 -20% 50% -0.10
# X F2 -15% 30% -0.05
# X F3 -25% 5% -0.01
#
#
# Additional Information:
# 1. There is a Geographical Level Hierarchy - Zone, Region
# 2. There is a Product Level Hierarchy- Manufacturer, Brand, Subbrand, Item
# 3. Pack Type and Pack Size are present under Item level
# 4. Formula for growth_rate = ( Value Sales (target_period) - Value Sales (reference_period) ) * 100 / Value Sales (reference_period)
# 5. Formula for contribution = Value Sales (F1) * 100 / Value Sales (X)
# 6. Formula for product = growth_rate * contribution

# %%
value_of_sales=4883.050
if value_of_sales<=4883.050:
    print('Their is a drop in the sales')
else:
    print('Sales is increase')
# Out:
# Their is a drop in the sales

# %%
Value_Of_ftake = 4883.050
print('sales price is 4883.050')
# Out:
# sales price is 4883.050

# %%
if Value_Of_ftake <= 4883.050:
    print('There is drop in the sales')
else:
    print('Their is no drop in the sales')
# Out:
# There is drop in the sales

# %%
CAGR = (4883.050/2993.130)**(1/6.0)-1
print ('Growth rate had a CAGR of {:.2%} '.format(CAGR))
# Out:
# Growth rate had a CAGR of 8.50%

# %%
case_study.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280 entries, 0 to 1279
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Zone                   1280 non-null   int32
#  1   Region                 1280 non-null   int32
#  2   Manufacturer           1280 non-null   int32
#  3   Brand                  1280 non-null   int32
#  4   Subbrand               1280 non-null   int64
#  5   Item                   1280 non-null   int32
#  6   PackSize               1280 non-null   int32
#  7   Packtype               1280 non-null   int32
#  8   month                  1280 non-null   datetime64[ns]
#  9   Value Offtake(000 Rs)  1280 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int32(7), int64(1)
# memory usage: 65.1 KB

# %%
case_study.tail()
# Out:
#       Zone  Region  Manufacturer  Brand  Subbrand  Item  PackSize  Packtype  \
# 1275     3       1             4      5         7    18         2         1
# 1276     3       1             4      5         7    25         2         1
# 1277     3       1             4      5         7    26         2         1
# 1278     3       1             4      5         7    27         2         1
# 1279     3       1             4      5         7    28         2         1
#
#           month  Value Offtake(000 Rs)
# 1275 2019-05-01                954.106
# 1276 2019-05-01                361.682
# 1277 2019-05-01                352.389
# 1278 2019-05-01                320.917
# 1279 2019-05-01                245.041

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
case_study['Zone'] = le.fit_transform(case_study['Zone'])
case_study
# Out:
#       Zone  Region  Manufacturer  Brand  Subbrand  Item  PackSize  Packtype  \
# 0        0       0             1      4         6    12         3         1
# 1        0       0             1      4         8    30         3         1
# 2        0       0             1      1         2     6         3         1
# 3        0       0             1      4         5    10         3         1
# 4        0       0             1      1         1     5         3         1
# ...    ...     ...           ...    ...       ...   ...       ...       ...
# 1275     3       1             4      5         7    18         2         1
# 1276     3       1             4      5         7    25         2         1
# 1277     3       1             4      5         7    26         2         1
# 1278     3       1             4      5         7    27         2         1
# 1279     3       1             4      5         7    28         2         1
#
#           month  Value Offtake(000 Rs)
# ...

# %%
case_study['Region'] = le.fit_transform(case_study['Region'])
case_study
# Out:
#       Zone  Region  Manufacturer  Brand  Subbrand  Item  PackSize  Packtype  \
# 0        0       0             1      4         6    12         3         1
# 1        0       0             1      4         8    30         3         1
# 2        0       0             1      1         2     6         3         1
# 3        0       0             1      4         5    10         3         1
# 4        0       0             1      1         1     5         3         1
# ...    ...     ...           ...    ...       ...   ...       ...       ...
# 1275     3       1             4      5         7    18         2         1
# 1276     3       1             4      5         7    25         2         1
# 1277     3       1             4      5         7    26         2         1
# 1278     3       1             4      5         7    27         2         1
# 1279     3       1             4      5         7    28         2         1
#
#           month  Value Offtake(000 Rs)
# ...

# %%
case_study['Manufacturer'] = le.fit_transform(case_study['Manufacturer'])
case_study
# Out:
#       Zone  Region  Manufacturer  Brand  Subbrand  Item  PackSize  Packtype  \
# 0        0       0             1      4         6    12         3         1
# 1        0       0             1      4         8    30         3         1
# 2        0       0             1      1         2     6         3         1
# 3        0       0             1      4         5    10         3         1
# 4        0       0             1      1         1     5         3         1
# ...    ...     ...           ...    ...       ...   ...       ...       ...
# 1275     3       1             4      5         7    18         2         1
# 1276     3       1             4      5         7    25         2         1
# 1277     3       1             4      5         7    26         2         1
# 1278     3       1             4      5         7    27         2         1
# 1279     3       1             4      5         7    28         2         1
#
#           month  Value Offtake(000 Rs)
# ...

# %%
case_study['Brand'] = le.fit_transform(case_study['Brand'])
case_study
# Out:
#       Zone  Region  Manufacturer  Brand  Subbrand  Item  PackSize  Packtype  \
# 0        0       0             1      4         6    12         3         1
# 1        0       0             1      4         8    30         3         1
# 2        0       0             1      1         2     6         3         1
# 3        0       0             1      4         5    10         3         1
# 4        0       0             1      1         1     5         3         1
# ...    ...     ...           ...    ...       ...   ...       ...       ...
# 1275     3       1             4      5         7    18         2         1
# 1276     3       1             4      5         7    25         2         1
# 1277     3       1             4      5         7    26         2         1
# 1278     3       1             4      5         7    27         2         1
# 1279     3       1             4      5         7    28         2         1
#
#           month  Value Offtake(000 Rs)
# ...

# %%
case_study['Subbrand'] = le.fit_transform(case_study['Subbrand'])
case_study
# Out:
#       Zone  Region  Manufacturer  Brand  Subbrand  Item  PackSize  Packtype  \
# 0        0       0             1      4         6    12         3         1
# 1        0       0             1      4         8    30         3         1
# 2        0       0             1      1         2     6         3         1
# 3        0       0             1      4         5    10         3         1
# 4        0       0             1      1         1     5         3         1
# ...    ...     ...           ...    ...       ...   ...       ...       ...
# 1275     3       1             4      5         7    18         2         1
# 1276     3       1             4      5         7    25         2         1
# 1277     3       1             4      5         7    26         2         1
# 1278     3       1             4      5         7    27         2         1
# 1279     3       1             4      5         7    28         2         1
#
#           month  Value Offtake(000 Rs)
# ...

# %%
case_study['Subbrand'] = le.fit_transform(case_study['Subbrand'])
case_study
# Out:
#       Zone  Region  Manufacturer  Brand  Subbrand  Item  PackSize  Packtype  \
# 0        0       0             1      4         6    12         3         1
# 1        0       0             1      4         8    30         3         1
# 2        0       0             1      1         2     6         3         1
# 3        0       0             1      4         5    10         3         1
# 4        0       0             1      1         1     5         3         1
# ...    ...     ...           ...    ...       ...   ...       ...       ...
# 1275     3       1             4      5         7    18         2         1
# 1276     3       1             4      5         7    25         2         1
# 1277     3       1             4      5         7    26         2         1
# 1278     3       1             4      5         7    27         2         1
# 1279     3       1             4      5         7    28         2         1
#
#           month  Value Offtake(000 Rs)
# ...

# %%
case_study['Item'] = le.fit_transform(case_study['Item'])
case_study
# Out:
#       Zone  Region  Manufacturer  Brand  Subbrand  Item  PackSize  Packtype  \
# 0        0       0             1      4         6    12         3         1
# 1        0       0             1      4         8    30         3         1
# 2        0       0             1      1         2     6         3         1
# 3        0       0             1      4         5    10         3         1
# 4        0       0             1      1         1     5         3         1
# ...    ...     ...           ...    ...       ...   ...       ...       ...
# 1275     3       1             4      5         7    18         2         1
# 1276     3       1             4      5         7    25         2         1
# 1277     3       1             4      5         7    26         2         1
# 1278     3       1             4      5         7    27         2         1
# 1279     3       1             4      5         7    28         2         1
#
#           month  Value Offtake(000 Rs)
# ...

# %%
case_study['PackSize'] = le.fit_transform(case_study['PackSize'])
case_study
# Out:
#       Zone  Region  Manufacturer  Brand  Subbrand  Item  PackSize  Packtype  \
# 0        0       0             1      4         6    12         3         1
# 1        0       0             1      4         8    30         3         1
# 2        0       0             1      1         2     6         3         1
# 3        0       0             1      4         5    10         3         1
# 4        0       0             1      1         1     5         3         1
# ...    ...     ...           ...    ...       ...   ...       ...       ...
# 1275     3       1             4      5         7    18         2         1
# 1276     3       1             4      5         7    25         2         1
# 1277     3       1             4      5         7    26         2         1
# 1278     3       1             4      5         7    27         2         1
# 1279     3       1             4      5         7    28         2         1
#
#           month  Value Offtake(000 Rs)
# ...

# %%
case_study['Packtype'] = le.fit_transform(case_study['Packtype'])
case_study
# Out:
#       Zone  Region  Manufacturer  Brand  Subbrand  Item  PackSize  Packtype  \
# 0        0       0             1      4         6    12         3         1
# 1        0       0             1      4         8    30         3         1
# 2        0       0             1      1         2     6         3         1
# 3        0       0             1      4         5    10         3         1
# 4        0       0             1      1         1     5         3         1
# ...    ...     ...           ...    ...       ...   ...       ...       ...
# 1275     3       1             4      5         7    18         2         1
# 1276     3       1             4      5         7    25         2         1
# 1277     3       1             4      5         7    26         2         1
# 1278     3       1             4      5         7    27         2         1
# 1279     3       1             4      5         7    28         2         1
#
#           month  Value Offtake(000 Rs)
# ...

# %%
X = case_study.drop(['month','Value Offtake(000 Rs)'],axis=1)

# %%
X = case_study['Manufacturer']

# %%
X
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1275    4
# 1276    4
# 1277    4
# 1278    4
# 1279    4
# Name: Manufacturer, Length: 1280, dtype: int64

# %%
y = case_study.target
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-4855b04e8a19> in <module>
# ----> 1 y = case_study.target
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'target'

# %%
y
# Out:
# 0      2019-01-01
# 1      2019-01-01
# 2      2019-01-01
# 3      2019-01-01
# 4      2019-01-01
#           ...
# 1275   2019-05-01
# 1276   2019-05-01
# 1277   2019-05-01
# 1278   2019-05-01
# 1279   2019-05-01
# Name: month, Length: 1280, dtype: datetime64[ns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test=train_test_split(X,y,test_size=0.30)

# %%
x_train.head()
# Out:
# 32     1
# 513    1
# 688    2
# 727    0
# 200    1
# Name: Manufacturer, dtype: int32

# %%
x_test.head()
# Out:
# 476     4
# 1222    1
# 1254    1
# 432     2
# 1024    1
# Name: Manufacturer, dtype: int32

# %%
x_train.shape
# Out:
# (896,)

# %%
y_train.shape
# Out:
# (896,)

# %%
x_test.shape
# Out:
# (384,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB,ComplementNB,CategoricalNB,BernoulliNB,MultinomialNB
from sklearn.ensemble import BaggingClassifier,AdaBoostClassifier,GradientBoostingClassifier,RandomForestClassifier,ExtraTreesClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split,validation_curve,learning_curve

# %%
model = SVC(kernel='linear',C=1E10)

# %%
model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-4c1a2828403e> in <module>
# ----> 1 model.fit(X,y)
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     160             X, y = self._validate_data(X, y, dtype=np.float64,
#     161                                        order='C', accept_sparse='csr',
# --> 162                                        accept_large_sparse=False)
#     163
#     164         y = self._validate_targets(y)
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
# ...
